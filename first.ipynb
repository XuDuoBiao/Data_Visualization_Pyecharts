# %%
import pyecharts
from pyecharts import Bar
#from pyecharts.echarts import Bar

# %% [markdown]
# ## 柱状图Bar

# %%
#导入柱状图-Bar
from pyecharts import Bar
#设置行名
columns = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
#设置数据
data1 = [2.0, 4.9, 7.0, 23.2, 25.6, 76.7, 135.6, 162.2, 32.6, 20.0, 6.4, 3.3]
data2 = [2.6, 5.9, 9.0, 26.4, 28.7, 70.7, 175.6, 182.2, 48.7, 18.8, 6.0, 2.3]
#设置柱状图的主标题与副标题
bar = Bar("柱状图", "一年的降水量与蒸发量")
#添加柱状图的数据及配置项
bar.add("降水量", columns, data1, mark_line=["average"], mark_point=["max", "min"])
bar.add("蒸发量", columns, data2, mark_line=["average"], mark_point=["max", "min"])
#生成本地文件（默认为.html文件）
bar.render()

# %%
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="fd4cc5bcbbdc4df7b038d3707247ed18" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_fd4cc5bcbbdc4df7b038d3707247ed18 = echarts.init(document.getElementById('fd4cc5bcbbdc4df7b038d3707247ed18'), 'light', {renderer: 'canvas'});
#
# var option_fd4cc5bcbbdc4df7b038d3707247ed18 = {
#     "title": [
#         {
#             "text": "\u67f1\u72b6\u56fe",
#             "subtext": "\u4e00\u5e74\u7684\u964d\u6c34\u91cf\u4e0e\u84b8\u53d1\u91cf",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 1571820,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u964d\u6c34\u91cf",
#             "data": [
#                 2.0,
#                 4.9,
#                 7.0,
#                 23.2,
#                 25.6,
#                 76.7,
#                 135.6,
#                 162.2,
#                 32.6,
#                 20.0,
#                 6.4,
#                 3.3
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "type": "max",
#                         "name": "Maximum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     },
#                     {
#                         "type": "min",
#                         "name": "Minimum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     }
#                 ]
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "seriesId": 1571820
#         },
#         {
#             "type": "bar",
#             "name": "\u84b8\u53d1\u91cf",
#             "data": [
#                 2.6,
#                 5.9,
#                 9.0,
#                 26.4,
#                 28.7,
#                 70.7,
#                 175.6,
#                 182.2,
#                 48.7,
#                 18.8,
#                 6.0,
#                 2.3
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "type": "max",
#                         "name": "Maximum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     },
#                     {
#                         "type": "min",
#                         "name": "Minimum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     }
#                 ]
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "seriesId": 1571820
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u964d\u6c34\u91cf",
#                 "\u84b8\u53d1\u91cf"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "Jan",
#                 "Feb",
#                 "Mar",
#                 "Apr",
#                 "May",
#                 "Jun",
#                 "Jul",
#                 "Aug",
#                 "Sep",
#                 "Oct",
#                 "Nov",
#                 "Dec"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true

# %% [markdown]
# ## 饼图Pie

# %%
#导入饼图Pie
from pyecharts import Pie
#设置主标题与副标题，标题设置居中，设置宽度为900
pie = Pie("饼状图", "一年的降水量与蒸发量",title_pos='center',width=900)
#加入数据，设置坐标位置为【40，90】，上方的colums选项取消显示
pie.add("降水量", columns, data1 ,center=[25,50],is_legend_show=True,is_label_show=True)
#加入数据，设置坐标位置为【90，90】，上方的colums选项取消显示，显示label标签
pie.add("蒸发量", columns, data2 ,center=[75,50],is_legend_show=True,is_label_show=True)
#保存图表
pie.render()

pie
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="b8720cc2f0f44df0a064d0983ec1db54" style="width:900px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_b8720cc2f0f44df0a064d0983ec1db54 = echarts.init(document.getElementById('b8720cc2f0f44df0a064d0983ec1db54'), 'light', {renderer: 'canvas'});
#
# var option_b8720cc2f0f44df0a064d0983ec1db54 = {
#     "title": [
#         {
#             "text": "\u997c\u72b6\u56fe",
#             "subtext": "\u4e00\u5e74\u7684\u964d\u6c34\u91cf\u4e0e\u84b8\u53d1\u91cf",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 3736473,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "pie",
#             "name": "\u964d\u6c34\u91cf",
#             "data": [
#                 {
#                     "name": "Jan",
#                     "value": 2.0
#                 },
#                 {
#                     "name": "Feb",
#                     "value": 4.9
#                 },
#                 {
#                     "name": "Mar",
#                     "value": 7.0
#                 },
#                 {
#                     "name": "Apr",
#                     "value": 23.2
#                 },
#                 {
#                     "name": "May",
#                     "value": 25.6
#                 },
#                 {
#                     "name": "Jun",
#                     "value": 76.7
#                 },
#                 {
#                     "name": "Jul",
#                     "value": 135.6
#                 },
#                 {
#                     "name": "Aug",
#                     "value": 162.2
#                 },
#                 {
#                     "name": "Sep",
#                     "value": 32.6
#                 },
#                 {
#                     "name": "Oct",
#                     "value": 20.0
#                 },
#                 {
#                     "name": "Nov",
#                     "value": 6.4
#                 },
#                 {
#                     "name": "Dec",
#                     "value": 3.3
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "25%",
#                 "50%"
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "seriesId": 3736473
#         },
#         {
#             "type": "pie",
#             "name": "\u84b8\u53d1\u91cf",
#             "data": [
#                 {
#                     "name": "Jan",
#                     "value": 2.6
#                 },
#                 {
#                     "name": "Feb",
#                     "value": 5.9
#                 },
#                 {
#                     "name": "Mar",
#                     "value": 9.0
#                 },
#                 {
#                     "name": "Apr",
#                     "value": 26.4
#                 },
#                 {
#                     "name": "May",
#                     "value": 28.7
#                 },
#                 {
#                     "name": "Jun",
#                     "value": 70.7
#                 },
#                 {
#                     "name": "Jul",
#                     "value": 175.6
#                 },
#                 {
#                     "name": "Aug",
#                     "value": 182.2
#                 },
#                 {
#                     "name": "Sep",
#                     "value": 48.7
#                 },
#                 {
#                     "name": "Oct",
#                     "value": 18.8
#                 },
#                 {
#                     "name": "Nov",
#                     "value": 6.0
#                 },
#                 {
#                     "name": "Dec",
#                     "value": 2.3
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "75%",
#                 "50%"
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "seriesId": 3736473
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Jan",
#                 "Feb",
#                 "Mar",
#                 "Apr",
#                 "May",
#                 "Jun",
#                 "Jul",
#                 "Aug",
#                 "Sep",
#                 "Oct",
#                 "Nov",
#                 "Dec"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_b8720cc2f0f44df0a064d0983ec1db54.setOption(option_b8720cc2f0f44df0a064d0983ec1db54);
#
#     });
# </script>

# %% [markdown]
# ## 箱体图-Boxplot

# %%
#导入箱型图Boxplot
from pyecharts import Boxplot 
boxplot = Boxplot("箱形图", "一年的降水量与蒸发量")
x_axis = ['降水量','蒸发量']
y_axis = [data1,data2]
#prepare_data方法可以将数据转为嵌套的 [min, Q1, median (or Q2), Q3, max]
yaxis = boxplot.prepare_data(y_axis) 
boxplot.add("天气统计", x_axis, y_axis)
boxplot.render()

boxplot
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="0129e4a82ccc48aba986a2c82ff0ec27" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_0129e4a82ccc48aba986a2c82ff0ec27 = echarts.init(document.getElementById('0129e4a82ccc48aba986a2c82ff0ec27'), 'light', {renderer: 'canvas'});
#
# var option_0129e4a82ccc48aba986a2c82ff0ec27 = {
#     "title": [
#         {
#             "text": "\u7bb1\u5f62\u56fe",
#             "subtext": "\u4e00\u5e74\u7684\u964d\u6c34\u91cf\u4e0e\u84b8\u53d1\u91cf",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 4977724,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "boxplot",
#             "name": "\u5929\u6c14\u7edf\u8ba1",
#             "data": [
#                 [
#                     2.0,
#                     4.9,
#                     7.0,
#                     23.2,
#                     25.6,
#                     76.7,
#                     135.6,
#                     162.2,
#                     32.6,
#                     20.0,
#                     6.4,
#                     3.3
#                 ],
#                 [
#                     2.6,
#                     5.9,
#                     9.0,
#                     26.4,
#                     28.7,
#                     70.7,
#                     175.6,
#                     182.2,
#                     48.7,
#                     18.8,
#                     6.0,
#                     2.3
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 4977724
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5929\u6c14\u7edf\u8ba1"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "\u964d\u6c34\u91cf",
#                 "\u84b8\u53d1\u91cf"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_0129e4a82ccc48aba986a2c82ff0ec27.setOption(option_0129e4a82ccc48aba986a2c82ff0ec27);
#
#     });
# </script>

# %% [markdown]
# ## 折线图-Line

# %%
# 导入折线图
from pyecharts import Line
line = Line("折线图","一年的降水量与蒸发量")
#is_label_show是设置上方数据是否显示
line.add("降水量", columns, data1, is_label_show=True)
line.add("蒸发量", columns, data2, is_label_show=True)
line.render()

line
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="b898519c569e44b9ba5f029102593b9e" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_b898519c569e44b9ba5f029102593b9e = echarts.init(document.getElementById('b898519c569e44b9ba5f029102593b9e'), 'light', {renderer: 'canvas'});
#
# var option_b898519c569e44b9ba5f029102593b9e = {
#     "title": [
#         {
#             "text": "\u6298\u7ebf\u56fe",
#             "subtext": "\u4e00\u5e74\u7684\u964d\u6c34\u91cf\u4e0e\u84b8\u53d1\u91cf",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 721520,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "\u964d\u6c34\u91cf",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "Jan",
#                     2.0
#                 ],
#                 [
#                     "Feb",
#                     4.9
#                 ],
#                 [
#                     "Mar",
#                     7.0
#                 ],
#                 [
#                     "Apr",
#                     23.2
#                 ],
#                 [
#                     "May",
#                     25.6
#                 ],
#                 [
#                     "Jun",
#                     76.7
#                 ],
#                 [
#                     "Jul",
#                     135.6
#                 ],
#                 [
#                     "Aug",
#                     162.2
#                 ],
#                 [
#                     "Sep",
#                     32.6
#                 ],
#                 [
#                     "Oct",
#                     20.0
#                 ],
#                 [
#                     "Nov",
#                     6.4
#                 ],
#                 [
#                     "Dec",
#                     3.3
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 721520
#         },
#         {
#             "type": "line",
#             "name": "\u84b8\u53d1\u91cf",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "Jan",
#                     2.6
#                 ],
#                 [
#                     "Feb",
#                     5.9
#                 ],
#                 [
#                     "Mar",
#                     9.0
#                 ],
#                 [
#                     "Apr",
#                     26.4
#                 ],
#                 [
#                     "May",
#                     28.7
#                 ],
#                 [
#                     "Jun",
#                     70.7
#                 ],
#                 [
#                     "Jul",
#                     175.6
#                 ],
#                 [
#                     "Aug",
#                     182.2
#                 ],
#                 [
#                     "Sep",
#                     48.7
#                 ],
#                 [
#                     "Oct",
#                     18.8
#                 ],
#                 [
#                     "Nov",
#                     6.0
#                 ],
#                 [
#                     "Dec",
#                     2.3
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 721520
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u964d\u6c34\u91cf",
#                 "\u84b8\u53d1\u91cf"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "Jan",
#                 "Feb",
#                 "Mar",
#                 "Apr",
#                 "May",
#                 "Jun",
#                 "Jul",
#                 "Aug",
#                 "Sep",
#                 "Oct",
#                 "Nov",
#                 "Dec"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },

# %% [markdown]
# ## 雷达图-Rader

# %%
from pyecharts import Radar
radar = Radar("雷达图", "一年的降水量与蒸发量")
#由于雷达图传入的数据得为多维数据，所以这里需要做一下处理
radar_data1 = [[2.0, 4.9, 7.0, 23.2, 25.6, 76.7, 135.6, 162.2, 32.6, 20.0, 6.4, 3.3]]
radar_data2 = [[2.6, 5.9, 9.0, 26.4, 28.7, 70.7, 175.6, 182.2, 48.7, 18.8, 6.0, 2.3]]
#设置column的最大值，为了雷达图更为直观，这里的月份最大值设置有所不同
schema = [ 
 ("Jan", 5), ("Feb",10), ("Mar", 10),
 ("Apr", 50), ("May", 50), ("Jun", 200),
 ("Jul", 200), ("Aug", 200), ("Sep", 50),
 ("Oct", 50), ("Nov", 10), ("Dec", 5)
]
#传入坐标
radar.config(schema)
radar.add("降水量",radar_data1)
#一般默认为同一种颜色，这里为了便于区分，需要设置item的颜色
radar.add("蒸发量",radar_data2,item_color="#1C86EE")
radar.render()

radar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="3041b553fde341dfb4d232cf23c6f89b" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_3041b553fde341dfb4d232cf23c6f89b = echarts.init(document.getElementById('3041b553fde341dfb4d232cf23c6f89b'), 'light', {renderer: 'canvas'});
#
# var option_3041b553fde341dfb4d232cf23c6f89b = {
#     "title": [
#         {
#             "text": "\u96f7\u8fbe\u56fe",
#             "subtext": "\u4e00\u5e74\u7684\u964d\u6c34\u91cf\u4e0e\u84b8\u53d1\u91cf",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 212122,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "radar",
#             "name": "\u964d\u6c34\u91cf",
#             "data": [
#                 [
#                     2.0,
#                     4.9,
#                     7.0,
#                     23.2,
#                     25.6,
#                     76.7,
#                     135.6,
#                     162.2,
#                     32.6,
#                     20.0,
#                     6.4,
#                     3.3
#                 ]
#             ],
#             "symbol": "circle",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "itemStyle": {
#                 "normal": {}
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         },
#         {
#             "type": "radar",
#             "name": "\u84b8\u53d1\u91cf",
#             "data": [
#                 [
#                     2.6,
#                     5.9,
#                     9.0,
#                     26.4,
#                     28.7,
#                     70.7,
#                     175.6,
#                     182.2,
#                     48.7,
#                     18.8,
#                     6.0,
#                     2.3
#                 ]
#             ],
#             "symbol": "circle",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "itemStyle": {
#                 "normal": {
#                     "color": "#1C86EE"
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u964d\u6c34\u91cf",
#                 "\u84b8\u53d1\u91cf"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "radar": {
#         "indicator": [
#             {
#                 "name": "Jan",
#                 "max": 5
#             },
#             {
#                 "name": "Feb",
#                 "max": 10
#             },
#             {
#                 "name": "Mar",
#                 "max": 10
#             },
#             {
#                 "name": "Apr",
#                 "max": 50
#             },
#             {
#                 "name": "May",
#                 "max": 50
#             },
#             {
#                 "name": "Jun",
#                 "max": 200
#             },
#             {
#                 "name": "Jul",
#                 "max": 200
#             },
#             {
#                 "name": "Aug",
#                 "max": 200
#             },
#             {
#                 "name": "Sep",
#                 "max": 50
#             },
#             {
#                 "name": "Oct",
#                 "max": 50
#             },
#             {
#                 "name": "Nov",
#                 "max": 10
#             },
#             {
#                 "name": "Dec",
#                 "max": 5
#             }
#         ],
#         "name": {
#             "textStyle": {
#                 "color": "#333",
#                 "fontSize": 12
#             }
#         },
#         "splitLine": {
#             "show": true,
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         },
#         "splitArea": {
#             "show": true,
#             "areaStyle": {
#                 "opacity": 1
#             }
#         },
#         "axisLine": {
#             "show": true,
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     },
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_3041b553fde341dfb4d232cf23c6f89b.setOption(option_3041b553fde341dfb4d232cf23c6f89b);
#
#     });
# </script>

# %% [markdown]
# ## 散点图-scatter

# %%
from pyecharts import Scatter
scatter = Scatter("散点图", "一年的降水量与蒸发量")
#xais_name是设置横坐标名称，这里由于显示问题，还需要将y轴名称与y轴的距离进行设置
scatter.add("降水量与蒸发量的散点分布", data1,data2,xaxis_name="降水量",yaxis_name="蒸发量",yaxis_name_gap=40)
scatter.render()

scatter
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="0b2f224dee8645bb9e4bbf99888fc301" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_0b2f224dee8645bb9e4bbf99888fc301 = echarts.init(document.getElementById('0b2f224dee8645bb9e4bbf99888fc301'), 'light', {renderer: 'canvas'});
#
# var option_0b2f224dee8645bb9e4bbf99888fc301 = {
#     "title": [
#         {
#             "text": "\u6563\u70b9\u56fe",
#             "subtext": "\u4e00\u5e74\u7684\u964d\u6c34\u91cf\u4e0e\u84b8\u53d1\u91cf",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 8921957,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "scatter",
#             "name": "\u964d\u6c34\u91cf\u4e0e\u84b8\u53d1\u91cf\u7684\u6563\u70b9\u5206\u5e03",
#             "symbol": "circle",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     2.0,
#                     2.6
#                 ],
#                 [
#                     4.9,
#                     5.9
#                 ],
#                 [
#                     7.0,
#                     9.0
#                 ],
#                 [
#                     23.2,
#                     26.4
#                 ],
#                 [
#                     25.6,
#                     28.7
#                 ],
#                 [
#                     76.7,
#                     70.7
#                 ],
#                 [
#                     135.6,
#                     175.6
#                 ],
#                 [
#                     162.2,
#                     182.2
#                 ],
#                 [
#                     32.6,
#                     48.7
#                 ],
#                 [
#                     20.0,
#                     18.8
#                 ],
#                 [
#                     6.4,
#                     6.0
#                 ],
#                 [
#                     3.3,
#                     2.3
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 8921957
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u964d\u6c34\u91cf\u4e0e\u84b8\u53d1\u91cf\u7684\u6563\u70b9\u5206\u5e03"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "name": "\u964d\u6c34\u91cf",
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 2.0,
#                 4.9,
#                 7.0,
#                 23.2,
#                 25.6,
#                 76.7,
#                 135.6,
#                 162.2,
#                 32.6,
#                 20.0,
#                 6.4,
#                 3.3
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "\u84b8\u53d1\u91cf",
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 40,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_0b2f224dee8645bb9e4bbf99888fc301.setOption(option_0b2f224dee8645bb9e4bbf99888fc301);
#
#     });
# </script>

# %% [markdown]
# ##  图表布局 Grid

# %%
#由于标题与图表是属于两个不同的控件，所以这里必须对下方的图表Line进行标题位置设置，否则会出现标题重叠的bug。

from pyecharts import Grid

#设置折线图标题位置
line = Line("折线图","一年的降水量与蒸发量",title_top="45%")
line.add("降水量", columns, data1, is_label_show=True)
line.add("蒸发量", columns, data2, is_label_show=True)
grid = Grid()

#设置两个图表的相对位置
grid.add(bar, grid_bottom="60%")
grid.add(line, grid_top="60%")
grid.render()

grid
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="82a3f62804d74d3fa968635c20164e82" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_82a3f62804d74d3fa968635c20164e82 = echarts.init(document.getElementById('82a3f62804d74d3fa968635c20164e82'), 'light', {renderer: 'canvas'});
#
# var option_82a3f62804d74d3fa968635c20164e82 = {
#     "title": [
#         {
#             "text": "\u67f1\u72b6\u56fe",
#             "subtext": "\u4e00\u5e74\u7684\u964d\u6c34\u91cf\u4e0e\u84b8\u53d1\u91cf",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         },
#         {
#             "text": "\u6298\u7ebf\u56fe",
#             "subtext": "\u4e00\u5e74\u7684\u964d\u6c34\u91cf\u4e0e\u84b8\u53d1\u91cf",
#             "left": "auto",
#             "top": "45%",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 1571820,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u964d\u6c34\u91cf",
#             "data": [
#                 2.0,
#                 4.9,
#                 7.0,
#                 23.2,
#                 25.6,
#                 76.7,
#                 135.6,
#                 162.2,
#                 32.6,
#                 20.0,
#                 6.4,
#                 3.3
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "type": "max",
#                         "name": "Maximum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     },
#                     {
#                         "type": "min",
#                         "name": "Minimum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     }
#                 ]
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "seriesId": 1571820,
#             "xAxisIndex": 0,
#             "yAxisIndex": 0
#         },
#         {
#             "type": "bar",
#             "name": "\u84b8\u53d1\u91cf",
#             "data": [
#                 2.6,
#                 5.9,
#                 9.0,
#                 26.4,
#                 28.7,
#                 70.7,
#                 175.6,
#                 182.2,
#                 48.7,
#                 18.8,
#                 6.0,
#                 2.3
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "type": "max",
#                         "name": "Maximum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     },
#                     {
#                         "type": "min",
#                         "name": "Minimum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     }
#                 ]
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "seriesId": 1571820,
#             "xAxisIndex": 0,
#             "yAxisIndex": 0
#         },
#         {
#             "type": "line",
#             "name": "\u964d\u6c34\u91cf",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "Jan",
#                     2.0
#                 ],
#                 [
#                     "Feb",
#                     4.9
#                 ],
#                 [
#                     "Mar",
#                     7.0
#                 ],
#                 [
#                     "Apr",
#                     23.2
#                 ],
#                 [
#                     "May",
#                     25.6
#                 ],
#                 [
#                     "Jun",
#                     76.7
#                 ],
#                 [
#                     "Jul",
#                     135.6
#                 ],
#                 [
#                     "Aug",
#                     162.2
#                 ],
#                 [
#                     "Sep",
#                     32.6
#                 ],
#                 [
#                     "Oct",
#                     20.0
#                 ],
#                 [
#                     "Nov",
#                     6.4
#                 ],
#                 [
#                     "Dec",
#                     3.3
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",

# %% [markdown]
# ## 柱状图与折线图合并

# %%
from pyecharts import Overlap
overlap = Overlap()
bar = Bar("柱状图-折线图合并", "一年的降水量与蒸发量")
bar.add("降水量", columns, data1, mark_point=["max", "min"])
bar.add("蒸发量", columns, data2, mark_point=["max", "min"])
overlap.add(bar)
overlap.add(line)
overlap.render()

overlap
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="b64e9c680e364148bc7ddcf4764e01b9" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_b64e9c680e364148bc7ddcf4764e01b9 = echarts.init(document.getElementById('b64e9c680e364148bc7ddcf4764e01b9'), 'light', {renderer: 'canvas'});
#
# var option_b64e9c680e364148bc7ddcf4764e01b9 = {
#     "title": [
#         {
#             "text": "\u67f1\u72b6\u56fe-\u6298\u7ebf\u56fe\u5408\u5e76",
#             "subtext": "\u4e00\u5e74\u7684\u964d\u6c34\u91cf\u4e0e\u84b8\u53d1\u91cf",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 8579837,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u964d\u6c34\u91cf",
#             "data": [
#                 2.0,
#                 4.9,
#                 7.0,
#                 23.2,
#                 25.6,
#                 76.7,
#                 135.6,
#                 162.2,
#                 32.6,
#                 20.0,
#                 6.4,
#                 3.3
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "type": "max",
#                         "name": "Maximum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     },
#                     {
#                         "type": "min",
#                         "name": "Minimum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     }
#                 ]
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 8579837
#         },
#         {
#             "type": "bar",
#             "name": "\u84b8\u53d1\u91cf",
#             "data": [
#                 2.6,
#                 5.9,
#                 9.0,
#                 26.4,
#                 28.7,
#                 70.7,
#                 175.6,
#                 182.2,
#                 48.7,
#                 18.8,
#                 6.0,
#                 2.3
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "type": "max",
#                         "name": "Maximum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     },
#                     {
#                         "type": "min",
#                         "name": "Minimum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     }
#                 ]
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 8579837
#         },
#         {
#             "type": "line",
#             "name": "\u964d\u6c34\u91cf",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "Jan",
#                     2.0
#                 ],
#                 [
#                     "Feb",
#                     4.9
#                 ],
#                 [
#                     "Mar",
#                     7.0
#                 ],
#                 [
#                     "Apr",
#                     23.2
#                 ],
#                 [
#                     "May",
#                     25.6
#                 ],
#                 [
#                     "Jun",
#                     76.7
#                 ],
#                 [
#                     "Jul",
#                     135.6
#                 ],
#                 [
#                     "Aug",
#                     162.2
#                 ],
#                 [
#                     "Sep",
#                     32.6
#                 ],
#                 [
#                     "Oct",
#                     20.0
#                 ],
#                 [
#                     "Nov",
#                     6.4
#                 ],
#                 [
#                     "Dec",
#                     3.3
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 8579837,
#             "xAxisIndex": 0,
#             "yAxisI
