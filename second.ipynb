# %% [markdown]
# ## 地图Map

# %%
from pyecharts import Map, Geo

# %%
# 世界地图数据
value = [95.1, 23.2, 43.3, 66.4, 88.5]
attr= ["China", "Canada", "Brazil", "Russia", "United States"]

# 省和直辖市
province_distribution = {'河南': 45.23, '北京': 37.56, '河北': 21, '辽宁': 12, '江西': 6, '上海': 20, '安徽': 10, '江苏': 16, '湖南': 9, '浙江': 13, '海南': 2, '广东': 22, '湖北': 8, '黑龙江': 11, '澳门': 1, '陕西': 11, '四川': 7, '内蒙古': 3, '重庆': 3, '云南': 6, '贵州': 2, '吉林': 3, '山西': 12, '山东': 11, '福建': 4, '青海': 1, '舵主科技，质量保证': 1, '天津': 1, '其他': 1}
provice=list(province_distribution.keys())
values=list(province_distribution.values())

# 城市 -- 指定省的城市 xx市
city = ['郑州市', '安阳市', '洛阳市', '濮阳市', '南阳市', '开封市', '商丘市', '信阳市', '新乡市']
values2 = [1.07, 3.85, 6.38, 8.21, 2.53, 4.37, 9.38, 4.29, 6.1]

# 区县 -- 具体城市内的区县  xx县
quxian = ['夏邑县', '民权县', '梁园区', '睢阳区', '柘城县', '宁陵县']
values3 = [3, 5, 7, 8, 2, 4]

# %%
map0 = Map("世界地图示例", width=1200, height=600)
map0.add("世界地图", attr, value, maptype="world",  is_visualmap=True, visual_text_color='#000')
map0.render(path="04-00世界地图.html")
map0
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'world': '/nbextensions/echarts-countries-js/world'
#         }
#     });
# </script>
#     <div id="5ecab79240214b8da312a5c6e7e5ec5b" style="width:1200px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'world'], function(echarts) {
#
# var myChart_5ecab79240214b8da312a5c6e7e5ec5b = echarts.init(document.getElementById('5ecab79240214b8da312a5c6e7e5ec5b'), 'light', {renderer: 'canvas'});
#
# var option_5ecab79240214b8da312a5c6e7e5ec5b = {
#     "title": [
#         {
#             "text": "\u4e16\u754c\u5730\u56fe\u793a\u4f8b",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 1722424,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "map",
#             "name": "\u4e16\u754c\u5730\u56fe",
#             "symbol": "circle",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "mapType": "world",
#             "data": [
#                 {
#                     "name": "China",
#                     "value": 95.1
#                 },
#                 {
#                     "name": "Canada",
#                     "value": 23.2
#                 },
#                 {
#                     "name": "Brazil",
#                     "value": 43.3
#                 },
#                 {
#                     "name": "Russia",
#                     "value": 66.4
#                 },
#                 {
#                     "name": "United States",
#                     "value": 88.5
#                 }
#             ],
#             "roam": true,
#             "showLegendSymbol": true
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4e16\u754c\u5730\u56fe"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "visualMap": {
#         "type": "continuous",
#         "min": 0,
#         "max": 100,
#         "text": [
#             "high",
#             "low"
#         ],
#         "textStyle": {
#             "color": "#000"
#         },
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "left": "left",
#         "top": "bottom",
#         "showLabel": true
#     }
# };
# myChart_5ecab79240214b8da312a5c6e7e5ec5b.setOption(option_5ecab79240214b8da312a5c6e7e5ec5b);
#
#     });
# </script>

# %%
# maptype='china' 只显示全国直辖市和省级
# 数据只能是省名和直辖市的名称
map1 = Map("中国地图",'中国地图', width=1200, height=600)
map1.add("", provice, values, visual_range=[0, 50],  maptype='china', is_visualmap=True,visual_text_color='#000')
#map1.show_config()
map1.render(path="04-01中国地图.html")
map1
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts-countries-js/china'
#         }
#     });
# </script>
#     <div id="7486818450fc4b9e96e802731459b8cd" style="width:1200px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#
# var myChart_7486818450fc4b9e96e802731459b8cd = echarts.init(document.getElementById('7486818450fc4b9e96e802731459b8cd'), 'light', {renderer: 'canvas'});
#
# var option_7486818450fc4b9e96e802731459b8cd = {
#     "title": [
#         {
#             "text": "\u4e2d\u56fd\u5730\u56fe",
#             "subtext": "\u4e2d\u56fd\u5730\u56fe",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 8881052,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "map",
#             "symbol": "circle",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 45.23
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 37.56
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 21
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 12
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 6
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 20
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 10
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 16
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 9
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 13
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 22
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 8
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 11
#                 },
#                 {
#                     "name": "\u6fb3\u95e8",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 11
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 7
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 6
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 12
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 11
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u8235\u4e3b\u79d1\u6280\uff0c\u8d28\u91cf\u4fdd\u8bc1",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5176\u4ed6",
#                     "value": 1
#                 }
#             ],
#             "roam": true,
#             "showLegendSymbol": true
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "visualMap": {
#         "type": "continuous",
#         "min": 0,
#         "max": 50,
#         "text": [
#             "high",
#             "low"
#         ],
#         "textStyle": {
#             "color": "#000"
#         },
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "left": "left",
#         "top": "bottom",
#         "showLabel": true
#     }
# };
# myChart_7486818450fc4b9e96e802731459b8cd.setOption(option_7486818450fc4b9e96e802731459b8cd);
#
#     });
# </script>

# %%
# 河南地图  数据必须是省内放入城市名
map2 = Map("河南地图",'河南', width=1200, height=600)
map2.add('河南', city, values2, visual_range=[1, 10], maptype='河南', is_visualmap=True, visual_text_color='#000')
#map2.show_config()
map2.render(path="04-02河南地图.html")
map2
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'henan': '/nbextensions/echarts-china-provinces-js/henan'
#         }
#     });
# </script>
#     <div id="443354b47dc047d9ae1f36e6deed34f9" style="width:1200px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'henan'], function(echarts) {
#
# var myChart_443354b47dc047d9ae1f36e6deed34f9 = echarts.init(document.getElementById('443354b47dc047d9ae1f36e6deed34f9'), 'light', {renderer: 'canvas'});
#
# var option_443354b47dc047d9ae1f36e6deed34f9 = {
#     "title": [
#         {
#             "text": "\u6cb3\u5357\u5730\u56fe",
#             "subtext": "\u6cb3\u5357",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 2445617,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "map",
#             "name": "\u6cb3\u5357",
#             "symbol": "circle",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "mapType": "\u6cb3\u5357",
#             "data": [
#                 {
#                     "name": "\u90d1\u5dde\u5e02",
#                     "value": 1.07
#                 },
#                 {
#                     "name": "\u5b89\u9633\u5e02",
#                     "value": 3.85
#                 },
#                 {
#                     "name": "\u6d1b\u9633\u5e02",
#                     "value": 6.38
#                 },
#                 {
#                     "name": "\u6fee\u9633\u5e02",
#                     "value": 8.21
#                 },
#                 {
#                     "name": "\u5357\u9633\u5e02",
#                     "value": 2.53
#                 },
#                 {
#                     "name": "\u5f00\u5c01\u5e02",
#                     "value": 4.37
#                 },
#                 {
#                     "name": "\u5546\u4e18\u5e02",
#                     "value": 9.38
#                 },
#                 {
#                     "name": "\u4fe1\u9633\u5e02",
#                     "value": 4.29
#                 },
#                 {
#                     "name": "\u65b0\u4e61\u5e02",
#                     "value": 6.1
#                 }
#             ],
#             "roam": true,
#             "showLegendSymbol": true
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6cb3\u5357"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "visualMap": {
#         "type": "continuous",
#         "min": 1,
#         "max": 10,
#         "text": [
#             "high",
#             "low"
#         ],
#         "textStyle": {
#             "color": "#000"
#         },
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "left": "left",
#         "top": "bottom",
#         "showLabel": true
#     }
# };
# myChart_443354b47dc047d9ae1f36e6deed34f9.setOption(option_443354b47dc047d9ae1f36e6deed34f9);
#
#     });
# </script>

# %%
# # 商丘地图 数据为商丘市下的区县
map3 = Map("商丘地图",'商丘', width=1200, height=600)
map3.add("商丘", quxian, values3, visual_range=[1, 10], maptype='商丘', is_visualmap=True,
    visual_text_color='#000')
map3.render(path="04-03商丘地图.html")
map3
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'shang1_qiu1': '/nbextensions/echarts-china-cities-js/he2_nan2_shang1_qiu1'
#         }
#     });
# </script>
#     <div id="f5fa1f9e61524ea99cd01032a105b385" style="width:1200px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'shang1_qiu1'], function(echarts) {
#
# var myChart_f5fa1f9e61524ea99cd01032a105b385 = echarts.init(document.getElementById('f5fa1f9e61524ea99cd01032a105b385'), 'light', {renderer: 'canvas'});
#
# var option_f5fa1f9e61524ea99cd01032a105b385 = {
#     "title": [
#         {
#             "text": "\u5546\u4e18\u5730\u56fe",
#             "subtext": "\u5546\u4e18",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 140867,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "map",
#             "name": "\u5546\u4e18",
#             "symbol": "circle",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "mapType": "\u5546\u4e18",
#             "data": [
#                 {
#                     "name": "\u590f\u9091\u53bf",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u6c11\u6743\u53bf",
#                     "value": 5
#                 },
#                 {
#                     "name": "\u6881\u56ed\u533a",
#                     "value": 7
#                 },
#                 {
#                     "name": "\u7762\u9633\u533a",
#                     "value": 8
#                 },
#                 {
#                     "name": "\u67d8\u57ce\u53bf",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u5b81\u9675\u53bf",
#                     "value": 4
#                 }
#             ],
#             "roam": true,
#             "showLegendSymbol": true
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u4e18"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "visualMap": {
#         "type": "continuous",
#         "min": 1,
#         "max": 10,
#         "text": [
#             "high",
#             "low"
#         ],
#         "textStyle": {
#             "color": "#000"
#         },
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "left": "left",
#         "top": "bottom",
#         "showLabel": true
#     }
# };
# myChart_f5fa1f9e61524ea99cd01032a105b385.setOption(option_f5fa1f9e61524ea99cd01032a105b385);
#
#     });
# </script>

# %% [markdown]
# ## 下面的这两个可直接使用全国城市
#
# ## 热力分布图

# %%
data = [
("海门", 9),("鄂尔多斯", 12),("招远", 12),("舟山", 12),("齐齐哈尔", 14),("盐城", 15),
("赤峰", 16),("青岛", 18),("乳山", 18),("金昌", 19),("泉州", 21),("莱西", 21),
("日照", 21),("胶南", 22),("南通", 23),("拉萨", 24),("云浮", 24),("梅州", 25)]

attr, value = Geo.cast(data)

geo = Geo("全国主要城市空气质量热力图", "data from pm2.5", title_color="#fff", title_pos="center", width=1200, height=600,
          background_color='#404a59')

geo.add("空气质量热力图", attr, value, visual_range=[0, 25], type='heatmap',visual_text_color="#fff", symbol_size=15,
        is_visualmap=True, is_roam=False)
#geo.show_config()
geo.render(path="04-04空气质量热力图.html")
geo
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts-countries-js/china'
#         }
#     });
# </script>
#     <div id="230c57248234432eadf7d8178b620039" style="width:1200px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#
# var myChart_230c57248234432eadf7d8178b620039 = echarts.init(document.getElementById('230c57248234432eadf7d8178b620039'), 'light', {renderer: 'canvas'});
#
# var option_230c57248234432eadf7d8178b620039 = {
#     "title": [
#         {
#             "text": "\u5168\u56fd\u4e3b\u8981\u57ce\u5e02\u7a7a\u6c14\u8d28\u91cf\u70ed\u529b\u56fe",
#             "subtext": "data from pm2.5",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#fff",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 6860310,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": "{b}: {c}",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "heatmap",
#             "name": "\u7a7a\u6c14\u8d28\u91cf\u70ed\u529b\u56fe",
#             "coordinateSystem": "geo",
#             "data": [
#                 {
#                     "name": "\u6d77\u95e8",
#                     "value": [
#                         121.15,
#                         31.89,
#                         9
#                     ]
#                 },
#                 {
#                     "name": "\u9102\u5c14\u591a\u65af",
#                     "value": [
#                         109.781327,
#                         39.608266,
#                         12
#                     ]
#                 },
#                 {
#                     "name": "\u62db\u8fdc",
#                     "value": [
#                         120.38,
#                         37.35,
#                         12
#                     ]
#                 },
#                 {
#                     "name": "\u821f\u5c71",
#                     "value": [
#                         122.207216,
#                         29.985295,
#                         12
#                     ]
#                 },
#                 {
#                     "name": "\u9f50\u9f50\u54c8\u5c14",
#                     "value": [
#                         123.97,
#                         47.33,
#                         14
#                     ]
#                 },
#                 {
#                     "name": "\u76d0\u57ce",
#                     "value": [
#                         120.13,
#                         33.38,
#                         15
#                     ]
#                 },
#                 {
#                     "name": "\u8d64\u5cf0",
#                     "value": [
#                         118.87,
#                         42.28,
#                         16
#                     ]
#                 },
#                 {
#                     "name": "\u9752\u5c9b",
#                     "value": [
#                         120.33,
#                         36.07,
#                         18
#                     ]
#                 },
#                 {
#                     "name": "\u4e73\u5c71",
#                     "value": [
#                         121.52,
#                         36.89,
#                         18
#                     ]
#                 },
#                 {
#                     "name": "\u91d1\u660c",
#                     "value": [
#                         102.188043,
#                         38.520089,
#                         19
#                     ]
#                 },
#                 {
#                     "name": "\u6cc9\u5dde",
#                     "value": [
#                         118.58,
#                         24.93,
#                         21
#                     ]
#                 },
#                 {
#                     "name": "\u83b1\u897f",
#                     "value": [
#                         120.53,
#                         36.86,
#                         21
#                     ]
#                 },
#                 {
#                     "name": "\u65e5\u7167",
#                     "value": [
#                         119.46,
#                         35.42,
#                         21
#                     ]
#                 },
#                 {
#                     "name": "\u80f6\u5357",
#                     "value": [
#                         119.97,
#                         35.88,
#                         22
#                     ]
#                 },
#                 {
#                     "name": "\u5357\u901a",
#                     "value": [
#                         121.05,
#                         32.08,
#                         23
#                     ]
#                 },
#                 {
#                     "name": "\u62c9\u8428",
#                     "value": [
#                         91.11,
#                         29.97,
#                         24
#                     ]
#                 },
#                 {
#                     "name": "\u4e91\u6d6e",
#                     "value": [
#                         112.02,
#                         22.93,
#                         24
#                     ]
#                 },
#                 {
#                     "name": "\u6885\u5dde",
#                     "value": [
#                         116.1,
#                         24.55,
#                         25
#                     ]
#                 }
#             ]
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7a7a\u6c14\u8d28\u91cf\u70ed\u529b\u56fe"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "backgroundColor": "#404a59",
#     "animation": true,
#     "geo": {
#         "map": "china",
#         "roam": false,
#         "label": {
#             "emphasis": {
#                 "show": true,
#                 "textStyle": {
#                     "color": "#eee"
#                 }
#             }
#         },
#         "itemStyle": {
#             "normal": {
#                 "areaColor": "#323c48",
#                 "borderColor": "#111"
#             },
#             "emphasis": {
#                 "areaColor": "#2a333d"
#             }
#         }
#     },
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "visualMap": {
#         "type": "continuous",
#         "min": 0,
#         "max": 25,
#         "text": [
#             "high",
#             "low"
#         ],
#         "textStyle": {
#             "color": "#fff"
#         },
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "left": "le

# %%
# 空气质量评分
indexs = ['上海', '北京', '合肥', '哈尔滨', '广州', '成都', '无锡', '杭州', '武汉', '深圳', '西安', '郑州', '重庆', '长沙']
values = [4.07, 1.85, 4.38, 2.21, 3.53, 4.37, 1.38, 4.29, 4.1, 1.31, 3.92, 4.47, 2.40, 3.60]


geo2 = Geo("全国主要城市空气质量评分", "data from pm2.5", title_color="#fff", title_pos="center", width=1200, height=600,
          background_color='#404a59')

# type="effectScatter", is_random=True, effect_scale=5  使点具有发散性
geo2.add("空气质量评分", indexs, values, type="effectScatter", is_random=True, effect_scale=5, visual_range=[0, 5],
        visual_text_color="#fff", symbol_size=15, is_visualmap=True, is_roam=False)
#geo.show_config()
geo2.render(path="04-05空气质量评分.html")
geo2
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts-countries-js/china'
#         }
#     });
# </script>
#     <div id="4d925d1cf7b74f77acf10beb57c5fc37" style="width:1200px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#
# var myChart_4d925d1cf7b74f77acf10beb57c5fc37 = echarts.init(document.getElementById('4d925d1cf7b74f77acf10beb57c5fc37'), 'light', {renderer: 'canvas'});
#
# var option_4d925d1cf7b74f77acf10beb57c5fc37 = {
#     "title": [
#         {
#             "text": "\u5168\u56fd\u4e3b\u8981\u57ce\u5e02\u7a7a\u6c14\u8d28\u91cf\u8bc4\u5206",
#             "subtext": "data from pm2.5",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#fff",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 3387053,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": "{b}: {c}",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "effectScatter",
#             "name": "\u7a7a\u6c14\u8d28\u91cf\u8bc4\u5206",
#             "coordinateSystem": "geo",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "brushType": "stroke",
#                 "scale": 5,
#                 "period": 4
#             },
#             "symbol": "circle",
#             "symbolSize": 15,
#             "data": [
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         121.473701,
#                         31.230416,
#                         4.07
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         1.85
#                     ]
#                 },
#                 {
#                     "name": "\u5408\u80a5",
#                     "value": [
#                         117.27,
#                         31.86,
#                         4.38
#                     ]
#                 },
#                 {
#                     "name": "\u54c8\u5c14\u6ee8",
#                     "value": [
#                         126.63,
#                         45.75,
#                         2.21
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         3.53
#                     ]
#                 },
#                 {
#                     "name": "\u6210\u90fd",
#                     "value": [
#                         104.06,
#                         30.67,
#                         4.37
#                     ]
#                 },
#                 {
#                     "name": "\u65e0\u9521",
#                     "value": [
#                         120.29,
#                         31.59,
#                         1.38
#                     ]
#                 },
#                 {
#                     "name": "\u676d\u5dde",
#                     "value": [
#                         120.19,
#                         30.26,
#                         4.29
#                     ]
#                 },
#                 {
#                     "name": "\u6b66\u6c49",
#                     "value": [
#                         114.31,
#                         30.52,
#                         4.1
#                     ]
#                 },
#                 {
#                     "name": "\u6df1\u5733",
#                     "value": [
#                         114.07,
#                         22.62,
#                         1.31
#                     ]
#                 },
#                 {
#                     "name": "\u897f\u5b89",
#                     "value": [
#                         108.95,
#                         34.27,
#                         3.92
#                     ]
#                 },
#                 {
#                     "name": "\u90d1\u5dde",
#                     "value": [
#                         113.65,
#                         34.76,
#                         4.47
#                     ]
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": [
#                         106.551556,
#                         29.563009,
#                         2.4
#                     ]
#                 },
#                 {
#                     "name": "\u957f\u6c99",
#                     "value": [
#                         113,
#                         28.21,
#                         3.6
#                     ]
#                 }
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7a7a\u6c14\u8d28\u91cf\u8bc4\u5206"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "backgroundColor": "#404a59",
#     "animation": true,
#     "geo": {
#         "map": "china",
#         "roam": false,
#         "label": {
#             "emphasis": {
#                 "show": true,
#                 "textStyle": {
#                     "color": "#eee"
#                 }
#             }
#         },
#         "itemStyle": {
#             "normal": {
#                 "areaColor": "#323c48",
#                 "borderColor": "#111"
#             },
#             "emphasis": {
#                 "areaColor": "#2a333d"
#             }
#         }
#     },
#     "color": [
#         "#f6f5ec",
#         "#bda29a",
#         "#905a3d",
#         "#fab27b",
#         "#444693",
#         "#c4ccd3",
#         "#2f4554",
#         "#61a0a8",
#         "#726930",
#         "#ca8622",
#         "#d48265",
#         "#546570",
#         "#c23531",
#         "#6e7074",
#         "#ef5b9c",
#         "#1d953f",
#         "#ac6767",
#         "#f47920",
#         "#f05b72",
#         "#6d8346",
#         "#b2d235",
#         "#918597",
#         "#6950a1",
#         "#749f83",
#         "#2a5caa"
#     ],
#     "visualMap": {
#         "type": "continuous",
#         "min": 0,
#         "max": 5,
#         "text": [
#             "high",
#             "low"
#         ],
#         "textStyle": {
#             "color": "#fff"
#         },
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "left": "left",
#         "top": "bottom",
#         "showLabel": true
#     }
# };
# myChart_4d925d1cf7b74f77acf10beb57c5fc37.setOption(option_4d925d1cf7b74f77acf10beb57c5fc37);
#
#     });
# </script>
